# %% [markdown]
# ## trygonometria

# %% [markdown]
# <strong>wszystkow w html</strong>

# %% [markdown]
# <h2>Trygonometria</h2>
# <p>
#     Dział matematyki, który zajmuje się zależnościami między długościami boków,
#     a miarami kątów wewnętrznych w trójkątach. Rozszerzeniem podstawowej trygonometrii są tzw. funkcje trygonometryczne,
#     które często pojawiają się w analizie matematycznej.
# </p>
#
# <table>
#     <tr>
#         <th>&ang;</th>
#         <th>sin α</th>
#         <th>cos α</th>
#         <th>tg α</th>
#         <th>ctg α</th>
#     </tr>
#     <tr>
#         <th>30</th>
#         <td>&frac12;</td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <th>45</th>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <th>60</th>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <th>90</th>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
# </table>
