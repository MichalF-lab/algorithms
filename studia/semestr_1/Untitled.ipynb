# %% [markdown]
# pthom

# %% [markdown]
# Prezentacja na jakiś temat z liceum

# %% [markdown]
# # <strong>dziala</strong>

# %% [markdown]
# symbole zdj listy nagłowki

# %% [markdown]
# dziala jak natura chciała

# %% [markdown]
# $$
#     sqrt(2*8)
# $$
